# %%
import pandas as pd
STATION = "mroc"

# %%
data = pd.read_csv(f"metar_forecast/data/{STATION.upper()}/data.csv")
data.head()
# Out:
# /usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            Date  Year  Month  Day  Hour  Minute   Type Station  \
# 0  200501010000  2005      1    1     0       0  METAR    MROC
# 1  200501010100  2005      1    1     1       0  METAR    MROC
# 2  200501010200  2005      1    1     2       0  METAR    MROC
# 3  200501010300  2005      1    1     3       0  METAR    MROC
# 4  200501010400  2005      1    1     4       0  METAR    MROC
#
#    Wind_direction  Wind_speed  ...  Sky_layer3_cover  Sky_layer3_height  \
# 0           110.0        11.0  ...               NaN                NaN
# 1           100.0         7.0  ...               NaN                NaN
# 2             NaN         3.0  ...               NaN                NaN
# 3            60.0         8.0  ...               NaN                NaN
# 4            80.0         4.0  ...               NaN                NaN
#
#   Sky_layer3_cloud Sky_layer4_cover Sky_layer4_height Sky_layer4_cloud  \
# 0              NaN              NaN               NaN              NaN
# 1              NaN              NaN               NaN              NaN
# 2              NaN              NaN               NaN              NaN
# 3              NaN              NaN               NaN              NaN
# 4              NaN              NaN               NaN              NaN
#
#   Temperature  Dewpoint Pressure  \
# 0        22.0      17.0    29.94
# 1        22.0      17.0    29.97
# 2        22.0      17.0    29.99
# 3        21.0      17.0    30.00
# 4        20.0      17.0    30.01
#
#                                                 Code
# 0  METAR MROC 010000Z 11011KT 9999 FEW030 22/17 A...
# 1  METAR MROC 010100Z 10007KT 9999 FEW035 22/17 A...
# 2  METAR MROC 010200Z VRB03KT 9999 FEW035 22/17 A...
# 3  METAR MROC 010300Z 06008KT 9999 FEW030 21/17 A...
# 4  METAR MROC 010400Z 08004KT 9999 FEW030 20/17 A...
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Dirección del viento
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
wind_dir = data[["Date", "Wind_direction"]]
print(wind_dir.shape)
print(wind_dir.head())
# Out:
# (141034, 2)
#            Date  Wind_direction
# 0  200501010000           110.0
# 1  200501010100           100.0
# 2  200501010200             NaN
# 3  200501010300            60.0
# 4  200501010400            80.0

# %%
print(wind_dir["Wind_direction"].max())
print(wind_dir["Wind_direction"].min())
# Out:
# 360.0
# 0.0

# %% [markdown]
# ## Velocidad y ráfagas de viento
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
wind_speed = data[["Date", "Wind_speed", "Wind_gust"]]
print(wind_speed.shape)
print(wind_speed.head())
# Out:
# (141034, 3)
#            Date  Wind_speed  Wind_gust
# 0  200501010000        11.0        NaN
# 1  200501010100         7.0        NaN
# 2  200501010200         3.0        NaN
# 3  200501010300         8.0        NaN
# 4  200501010400         4.0        NaN

# %% [markdown]
# ### Velocidad del viento

# %%
print(wind_speed["Wind_speed"].max())
print(wind_speed["Wind_speed"].min())
# Out:
# 113.0
# 0.0

# %%
anomalias = wind_speed.query("Wind_speed > 30.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (9, 3)
#                 Date  Wind_speed  Wind_gust
# 5661    200509030700        94.0        NaN
# 25261   200712101000        98.0        NaN
# 37373   200904221600       112.0       22.0
# 47844   201006290900        94.0        NaN
# 56432   201106151000        70.0        NaN
# 71848   201303091100       113.0       27.0
# 91197   201505130400       111.0       21.0
# 112384  201709291700        75.0        NaN
# 115166  201801230500        98.0        NaN

# %% [markdown]
# ### Ráfagas de viento

# %%
print(wind_speed["Wind_gust"].max())
print(wind_speed["Wind_gust"].min())
# Out:
# 246.0
# 11.0

# %%
anomalias = wind_speed.query("Wind_gust > 40.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (8, 3)
#                 Date  Wind_speed  Wind_gust
# 17339   200701131800        23.0       43.0
# 17455   200701181400        23.0       43.0
# 17457   200701181600        23.0       42.0
# 97283   201601191600        21.0       41.0
# 114113  201712100800        21.0       45.0
# 132550  202001142100        27.0       42.0
# 133004  202002021800        26.0       41.0
# 133983  202003141200        16.0      246.0

# %% [markdown]
# # Visibilidad
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
visibility = data[["Date", "Visibility"]]
print(visibility.shape)
print(visibility.head())
# Out:
# (141034, 2)
#            Date  Visibility
# 0  200501010000     10000.0
# 1  200501010100     10000.0
# 2  200501010200     10000.0
# 3  200501010300     10000.0
# 4  200501010400     10000.0

# %%
print(visibility["Visibility"].max())
print(visibility["Visibility"].min())
# Out:
# 10000.0
# 50.0

# %% [markdown]
# # Altura de las bases de las nubes
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
heights = data[["Date", "Sky_layer1_height", "Sky_layer2_height", "Sky_layer3_height", "Sky_layer4_height"]]
print(heights.shape)
print(heights.head())
# Out:
# (141034, 5)
#            Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 0  200501010000             3000.0                NaN                NaN
# 1  200501010100             3500.0                NaN                NaN
# 2  200501010200             3500.0                NaN                NaN
# 3  200501010300             3000.0                NaN                NaN
# 4  200501010400             3000.0                NaN                NaN
#
#    Sky_layer4_height
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ### Sky_layer1

# %%
print(heights["Sky_layer1_height"].max())
print(heights["Sky_layer1_height"].min())
# Out:
# 903500.0
# 0.0

# %%
anomalias = heights.query("Sky_layer1_height > 25000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (22, 5)
#                 Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 15490   200610280100           901000.0             2500.0                NaN
# 19988   200705050500            99300.0            13000.0                NaN
# 24963   200711272300            93900.0            10000.0                NaN
# 29440   200805310800            27000.0                NaN                NaN
# 29441   200805310900            27000.0                NaN                NaN
# 30490   200807130800            99500.0             1500.0                NaN
# 30894   200807292200            92500.0            12000.0                NaN
# 32734   200810131500           900600.0             1500.0                NaN
# 35332   200901282200            43000.0            12000.0                NaN
# 39810   200908010100           303000.0            15000.0                NaN
# 40785   200909101500            52500.0                NaN                NaN
# 43246   200912210900            99200.0            12000.0                NaN
# 46872   201005200900            99400.0             1500.0                NaN
# 48037   201007070900            99200.0             2000.0            10000.0
# 50740   201010261100            30000.0                NaN                NaN
# 51342   201011201000            92500.0            10000.0                NaN
# 55802   201105201400            30000.0                NaN                NaN
# 55803   201105201500            30000.0                NaN                NaN
# 85939   201410090500            99800.0            20000.0                NaN
# 90628   201504192100           903500.0            14000.0                NaN
# 92215   201506240500            39000.0                NaN                NaN
# 116626  201803242300            31000.0                NaN                NaN
#
#         Sky_layer4_height
# 15490                 NaN
# 19988                 NaN
# 24963                 NaN
# 29440                 NaN
# 29441                 NaN
# 30490                 NaN
# 30894                 NaN
# 32734                 NaN
# 35332                 NaN
# 39810                 NaN
# 40785                 NaN
# 43246                 NaN
# 46872                 NaN
# 48037                 NaN
# 50740                 NaN
# 51342                 NaN
# 55802                 NaN
# 55803                 NaN
# 85939                 NaN
# 90628                 NaN
# 92215                 NaN
# 116626                NaN

# %% [markdown]
# ### Sky_layer2

# %%
print(heights["Sky_layer2_height"].max())
print(heights["Sky_layer2_height"].min())
# Out:
# 390000.0
# 200.0

# %%
anomalias = heights.query("Sky_layer2_height > 30000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (13, 5)
#                 Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 1403    200503032300             3000.0           390000.0                NaN
# 1420    200503041600             3500.0            35000.0                NaN
# 7389    200511150200              500.0           100000.0                NaN
# 23016   200709072200             1000.0            92500.0            10000.0
# 35065   200901172100             3000.0           132000.0            25000.0
# 49685   201009130100             1000.0            43000.0            10000.0
# 59235   201110080100             2000.0           100000.0            20000.0
# 69515   201212030100             3000.0           120200.0                NaN
# 78319   201311292100             3000.0           256000.0                NaN
# 105955  201701081900             3000.0           120000.0                NaN
# 110189  201706301800             4500.0            35000.0                NaN
# 111754  201709031400             4000.0            33000.0                NaN
# 113979  201712041800             4500.0            35000.0                NaN
#
#         Sky_layer4_height
# 1403                  NaN
# 1420                  NaN
# 7389                  NaN
# 23016                 NaN
# 35065                 NaN
# 49685                 NaN
# 59235                 NaN
# 69515                 NaN
# 78319                 NaN
# 105955                NaN
# 110189                NaN
# 111754                NaN
# 113979                NaN

# %% [markdown]
# ### Sky_layer3

# %%
print(heights["Sky_layer3_height"].max())
print(heights["Sky_layer3_height"].min())
# Out:
# 450000.0
# 400.0

# %%
anomalias = heights.query("Sky_layer3_height > 30000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (5, 5)
#                 Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 93613   201508210000             3000.0            12000.0           120000.0
# 102082  201608032100              500.0             1000.0           200000.0
# 102332  201608140100              600.0             1500.0           450000.0
# 109662  201706090500             1000.0             3000.0           122000.0
# 111686  201708311900             4500.0            25000.0            35000.0
#
#         Sky_layer4_height
# 93613                 NaN
# 102082                NaN
# 102332                NaN
# 109662                NaN
# 111686                NaN

# %% [markdown]
# ### Sky_layer4

# %%
print(heights["Sky_layer4_height"].max())
print(heights["Sky_layer4_height"].min())
# Out:
# 30000.0
# 1200.0

# %%
anomalias = heights.query("Sky_layer4_height > 25000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (2, 5)
#               Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 3289  200505231800             1000.0             3000.0            10000.0
# 4342  200507071900             1500.0             3000.0            12000.0
#
#       Sky_layer4_height
# 3289            30000.0
# 4342            26000.0

# %% [markdown]
# # Temperaturas
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
temperatures = data[["Date", "Temperature", "Dewpoint"]]
print(temperatures.shape)
print(temperatures.head())
# Out:
# (141034, 3)
#            Date  Temperature  Dewpoint
# 0  200501010000         22.0      17.0
# 1  200501010100         22.0      17.0
# 2  200501010200         22.0      17.0
# 3  200501010300         21.0      17.0
# 4  200501010400         20.0      17.0

# %% [markdown]
# ### Temperatura absoluta

# %%
print(temperatures["Temperature"].max())
print(temperatures["Temperature"].min())
# Out:
# 38.0
# 2.0

# %%
anomalias = temperatures.query("Temperature < 10.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (2, 3)
#                 Date  Temperature  Dewpoint
# 51777   201012080500          8.0      14.0
# 134006  202003151100          2.0      13.0

# %% [markdown]
# ### Dewpoint

# %%
print(temperatures["Dewpoint"].max())
print(temperatures["Dewpoint"].min())
# Out:
# 90.0
# 0.0

# %% [markdown]
# ### Checando cuando la temperatura de rocío es mayor a la absoluta, no debería ser.

# %%
anomalias = temperatures.query("Dewpoint > 30")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (3, 3)
#                Date  Temperature  Dewpoint
# 57661  201108050000         23.0      32.0
# 57662  201108050001         23.0      32.0
# 95476  201511052000         23.0      90.0

# %% [markdown]
# # Presión
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
pressure = data[["Date", "Pressure"]]
print(pressure.shape)
print(pressure.head())
# Out:
# (141034, 2)
#            Date  Pressure
# 0  200501010000     29.94
# 1  200501010100     29.97
# 2  200501010200     29.99
# 3  200501010300     30.00
# 4  200501010400     30.01

# %%
print(pressure["Pressure"].max())
print(pressure["Pressure"].min())
# Out:
# 39.93
# 29.77

# %%
anomalias = pressure.query("Pressure > 30.20")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (1, 2)
#                 Date  Pressure
# 139341  202010222200     39.93

# %%
anomalias = pressure.query("Pressure < 29.79")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (3, 2)
#                Date  Pressure
# 18462  200703012200     29.77
# 18484  200703022100     29.78
# 18485  200703022200     29.78
