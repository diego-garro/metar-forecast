# %%
import pandas as pd
STATION = "mrlb"

# %%
data = pd.read_csv(f"metar_forecast/data/{STATION.upper()}/data.csv")
data.head()
# Out:
# /usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (21,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            Date  Year  Month  Day  Hour  Minute   Type Station  \
# 0  200501010000  2005      1    1     0       0  METAR    MRLB
# 1  200501010100  2005      1    1     1       0  METAR    MRLB
# 2  200501010200  2005      1    1     2       0  METAR    MRLB
# 3  200501010300  2005      1    1     3       0  METAR    MRLB
# 4  200501010400  2005      1    1     4       0  METAR    MRLB
#
#    Wind_direction  Wind_speed  ...  Sky_layer3_cover  Sky_layer3_height  \
# 0             NaN         NaN  ...               NaN                NaN
# 1            80.0        15.0  ...               NaN                NaN
# 2             NaN         NaN  ...               NaN                NaN
# 3             NaN         NaN  ...               NaN                NaN
# 4             NaN         NaN  ...               NaN                NaN
#
#   Sky_layer3_cloud Sky_layer4_cover Sky_layer4_height Sky_layer4_cloud  \
# 0              NaN              NaN               NaN              NaN
# 1              NaN              NaN               NaN              NaN
# 2              NaN              NaN               NaN              NaN
# 3              NaN              NaN               NaN              NaN
# 4              NaN              NaN               NaN              NaN
#
#   Temperature  Dewpoint Pressure  \
# 0         NaN       NaN      NaN
# 1        27.0      19.0    29.84
# 2         NaN       NaN      NaN
# 3         NaN       NaN      NaN
# 4         NaN       NaN      NaN
#
#                                                 Code
# 0                                     METAR MRLB NIL
# 1  METAR MRLB 010100Z 08015KT 9999 FEW035 SCT250 ...
# 2                                     METAR MRLB NIL
# 3                                     METAR MRLB NIL
# 4                                     METAR MRLB NIL
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Dirección del viento
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
wind_dir = data[["Date", "Wind_direction"]]
print(wind_dir.shape)
print(wind_dir.head())
# Out:
# (138314, 2)
#            Date  Wind_direction
# 0  200501010000             NaN
# 1  200501010100            80.0
# 2  200501010200             NaN
# 3  200501010300             NaN
# 4  200501010400             NaN

# %%
print(wind_dir["Wind_direction"].max())
print(wind_dir["Wind_direction"].min())
# Out:
# 360.0
# 0.0

# %% [markdown]
# ## Velocidad y ráfagas de viento
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
wind_speed = data[["Date", "Wind_speed", "Wind_gust"]]
print(wind_speed.shape)
print(wind_speed.head())
# Out:
# (138314, 3)
#            Date  Wind_speed  Wind_gust
# 0  200501010000         NaN        NaN
# 1  200501010100        15.0        NaN
# 2  200501010200         NaN        NaN
# 3  200501010300         NaN        NaN
# 4  200501010400         NaN        NaN

# %% [markdown]
# ### Velocidad del viento

# %%
print(wind_speed["Wind_speed"].max())
print(wind_speed["Wind_speed"].min())
# Out:
# 33.0
# 0.0

# %%
anomalias = wind_speed.query("Wind_speed > 35.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 3)
# Empty DataFrame
# Columns: [Date, Wind_speed, Wind_gust]
# Index: []

# %% [markdown]
# ### Ráfagas de viento

# %%
print(wind_speed["Wind_gust"].max())
print(wind_speed["Wind_gust"].min())
# Out:
# 52.0
# 3.0

# %%
anomalias = wind_speed.query("Wind_gust > 45.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (10, 3)
#                 Date  Wind_speed  Wind_gust
# 112564  201802151500        31.0       49.0
# 121363  201902091700        29.0       46.0
# 121368  201902092200        28.0       46.0
# 121999  201903071800        30.0       50.0
# 122024  201903081900        26.0       46.0
# 129668  202001141400        30.0       47.0
# 130461  202002151500        32.0       48.0
# 130462  202002151600        30.0       52.0
# 131010  202003081700        32.0       47.0
# 131032  202003091500        32.0       46.0

# %% [markdown]
# # Visibilidad
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
visibility = data[["Date", "Visibility"]]
print(visibility.shape)
print(visibility.head())
# Out:
# (138314, 2)
#            Date  Visibility
# 0  200501010000         NaN
# 1  200501010100     10000.0
# 2  200501010200         NaN
# 3  200501010300         NaN
# 4  200501010400         NaN

# %%
print(visibility["Visibility"].max())
print(visibility["Visibility"].min())
# Out:
# 10000.0
# 0.0

# %% [markdown]
# # Altura de las bases de las nubes
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
heights = data[["Date", "Sky_layer1_height", "Sky_layer2_height", "Sky_layer3_height", "Sky_layer4_height"]]
print(heights.shape)
print(heights.head())
# Out:
# (138314, 5)
#            Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 0  200501010000                NaN                NaN                NaN
# 1  200501010100             3500.0            25000.0                NaN
# 2  200501010200                NaN                NaN                NaN
# 3  200501010300                NaN                NaN                NaN
# 4  200501010400                NaN                NaN                NaN
#
#    Sky_layer4_height
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ### Sky_layer1

# %%
print(heights["Sky_layer1_height"].max())
print(heights["Sky_layer1_height"].min())
# Out:
# 14000.0
# 100.0

# %%
anomalias = heights.query("Sky_layer1_height > 10000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (56, 5)
#                Date  Sky_layer1_height  Sky_layer2_height  Sky_layer3_height  \
# 2680   200504241200            14000.0            25000.0                NaN
# 2681   200504241300            13000.0            26000.0                NaN
# 8803   200601062000            12000.0                NaN                NaN
# 12028  200605222200            13000.0                NaN                NaN
# 13585  200607271400            11000.0                NaN                NaN
# 14709  200609122200            12000.0                NaN                NaN
# 16596  200612021800            12000.0                NaN                NaN
# 16597  200612021900            12000.0                NaN                NaN
# 21569  200707031600            12000.0                NaN                NaN
# 21661  200707071200            12000.0                NaN                NaN
# 21662  200707071300            12000.0                NaN                NaN
# 21668  200707071900            12000.0                NaN                NaN
# 21669  200707072000            12000.0                NaN                NaN
# 21670  200707072100            12000.0                NaN                NaN
# 21671  200707072200            12000.0                NaN                NaN
# 21672  200707072300            13000.0                NaN                NaN
# 21673  200707080000            13000.0                NaN                NaN
# 21674  200707080100            13000.0                NaN                NaN
# 21960  200707200000            12000.0                NaN                NaN
# 22069  200707241300            25000.0                NaN                NaN
# 22165  200707281200            14000.0                NaN                NaN
# 22261  200708011200            14000.0            25000.0                NaN
# 22356  200708051200            13000.0            25000.0                NaN
# 22428  200708081200            12000.0                NaN                NaN
# 22429  200708081300            12000.0                NaN                NaN
# 23146  200709071300            13000.0                NaN                NaN
# 23217  200709101200            13000.0            25000.0                NaN
# 23385  200709171200            12000.0                NaN                NaN
# 23672  200709291200            12000.0                NaN                NaN
# 23673  200709291300            12000.0                NaN                NaN
# 25691  200712231400            12000.0                NaN                NaN
# 29444  200805281400            12000.0                NaN                NaN
# 29734  200806091400            13000.0            25000.0                NaN
# 30968  200807310100            12000.0                NaN                NaN
# 31362  200808161200            13000.0            25000.0                NaN
# 31504  200808221200            12000.0                NaN                NaN
# 32369  200809271200            13000.0                NaN                NaN
# 32585  200810061200            13000.0                NaN                NaN
# 32945  200810211200            13000.0                NaN                NaN
# 32946  200810211300            13000.0                NaN                NaN
# 33376  200811081200            12000.0                NaN                NaN
# 37716  200905080100            12000.0                NaN                NaN
# 38232  200905291300            13000.0            13000.0                NaN
# 38643  200906151600            13000.0                NaN                NaN
# 39143  200907061200            13000.0                NaN                NaN
# 39937  200908081200            13000.0            25000.0                NaN
# 43248  200912250000            13000.0                NaN                NaN
# 43893  201001202100            14000.0                NaN                NaN
# 44639  201002202100            11000.0            25000.0                NaN
# 55235  201108051200            13000.0                NaN                NaN
# 55773  201108271700            12000.0            25000.0                NaN
# 63559  201207041400            12000.0                NaN                NaN
# 70825  201304201200            14000.0            25000.0                NaN
# 70826  201304201300            14000.0            25000.0                NaN
# 74603  201309172200            12000.0                NaN                NaN
# 99502  201609052200            12000.0                NaN                NaN
#
#        Sky_layer4_height
# 2680                 NaN
# 2681                 NaN
# 8803                 NaN
# 12028                NaN
# 13585                NaN
# 14709                NaN
# 16596                NaN
# 16597                NaN
# 21569                NaN
# 21661                NaN
# 21662                NaN
# 21668                NaN
# 21669                NaN
# 21670                NaN
# 21671                NaN
# 21672                NaN
# 21673                NaN
# 21674                NaN
# 21960                NaN
# 22069                NaN
# 22165                NaN
# 22261                NaN
# 22356                NaN
# 22428                NaN
# 22429                NaN
# 23146                NaN
# 23217                NaN
# 23385                NaN
# 23672                NaN
# 23673                NaN
# 25691                NaN
# 29444                NaN
# 29734                NaN
# 30968                NaN
# 31362                NaN
# 31504                NaN
# 32369                NaN
# 32585                NaN
# 32945                NaN
# 32946                NaN
# 33376                NaN
# 37716                NaN
# 38232                NaN
# 38643                NaN
# 39143                NaN
# 39937                NaN
# 43248                NaN
# 43893                NaN
# 44639                NaN
# 55235                NaN
# 55773                NaN
# 63559                NaN
# 70825                NaN
# 70826                NaN
# 74603                NaN
# 99502                NaN

# %% [markdown]
# ### Sky_layer2

# %%
print(heights["Sky_layer2_height"].max())
print(heights["Sky_layer2_height"].min())
# Out:
# 30000.0
# 400.0

# %%
anomalias = heights.query("Sky_layer2_height > 30000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 5)
# Empty DataFrame
# Columns: [Date, Sky_layer1_height, Sky_layer2_height, Sky_layer3_height, Sky_layer4_height]
# Index: []

# %% [markdown]
# ### Sky_layer3

# %%
print(heights["Sky_layer3_height"].max())
print(heights["Sky_layer3_height"].min())
# Out:
# 30000.0
# 1000.0

# %%
anomalias = heights.query("Sky_layer3_height > 30000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 5)
# Empty DataFrame
# Columns: [Date, Sky_layer1_height, Sky_layer2_height, Sky_layer3_height, Sky_layer4_height]
# Index: []

# %% [markdown]
# ### Sky_layer4

# %%
print(heights["Sky_layer4_height"].max())
print(heights["Sky_layer4_height"].min())
# Out:
# 25000.0
# 8000.0

# %%
anomalias = heights.query("Sky_layer4_height > 25000.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 5)
# Empty DataFrame
# Columns: [Date, Sky_layer1_height, Sky_layer2_height, Sky_layer3_height, Sky_layer4_height]
# Index: []

# %% [markdown]
# # Temperaturas
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
temperatures = data[["Date", "Temperature", "Dewpoint"]]
print(temperatures.shape)
print(temperatures.head())
# Out:
# (138314, 3)
#            Date  Temperature  Dewpoint
# 0  200501010000          NaN       NaN
# 1  200501010100         27.0      19.0
# 2  200501010200          NaN       NaN
# 3  200501010300          NaN       NaN
# 4  200501010400          NaN       NaN

# %% [markdown]
# ### Temperatura absoluta

# %%
print(temperatures["Temperature"].max())
print(temperatures["Temperature"].min())
# Out:
# 43.0
# 9.0

# %%
anomalias = temperatures.query("Temperature < 15.0")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (1, 3)
#                Date  Temperature  Dewpoint
# 90486  201508120000          9.0      19.0

# %% [markdown]
# ### Dewpoint

# %%
print(temperatures["Dewpoint"].max())
print(temperatures["Dewpoint"].min())
# Out:
# 33.0
# 0.0

# %% [markdown]
# ### Checando cuando la temperatura de rocío es mayor a la absoluta, no debería ser.

# %%
anomalias = temperatures.query("Dewpoint < 10")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (42, 3)
#                 Date  Temperature  Dewpoint
# 6587    200510052200         27.0       2.0
# 8802    200601061900         31.0       9.0
# 18246   200702091800         34.0       8.0
# 18247   200702091900         34.0       9.0
# 18413   200702161800         34.0       9.0
# 18414   200702161900         35.0       7.0
# 18415   200702162000         34.0       4.0
# 18416   200702162100         35.0       7.0
# 18417   200702162200         33.0       6.0
# 21235   200706191900         33.0       2.0
# 27016   200802162300         30.0       1.0
# 28756   200804300300         34.0       1.0
# 28888   200805051500         31.0       1.0
# 29183   200805171800         35.0       8.0
# 33641   200811192300         27.0       1.0
# 33947   200812021500         27.0       3.0
# 34386   200812202000         30.0       9.0
# 35235   200901250100         26.0       0.0
# 39434   200907181400         28.0       2.0
# 42545   200911251700         30.0       2.0
# 45103   201003120200         27.0       2.0
# 51612   201103071600         31.0       8.0
# 51613   201103071700         33.0       8.0
# 51614   201103071800         34.0       6.0
# 51615   201103071900         36.0       7.0
# 52525   201104141700         34.0       3.0
# 52526   201104141800         35.0       3.0
# 52527   201104141900         35.0       4.0
# 52528   201104142000         35.0       8.0
# 66679   201211051500         30.0       2.0
# 69623   201303031300         26.0       8.0
# 69624   201303031400         27.0       8.0
# 69625   201303031500         29.0       9.0
# 69626   201303031600         31.0       9.0
# 84290   201410091200         23.0       2.0
# 98053   201607092100         30.0       2.0
# 99407   201609020100         24.0       3.0
# 100614  201610192300         25.0       4.0
# 103618  201702171700         33.0       9.0
# 103619  201702171800         33.0       9.0
# 122377  201903230300         28.0       7.0
# 135274  202008292300         27.0       5.0

# %% [markdown]
# # Presión
#
# Revisando si hay datos anómalos que se peuedan corregir

# %%
pressure = data[["Date", "Pressure"]]
print(pressure.shape)
print(pressure.head())
# Out:
# (138314, 2)
#            Date  Pressure
# 0  200501010000       NaN
# 1  200501010100     29.84
# 2  200501010200       NaN
# 3  200501010300       NaN
# 4  200501010400       NaN

# %%
print(pressure["Pressure"].max())
print(pressure["Pressure"].min())
# Out:
# 30.11
# 29.6

# %%
anomalias = pressure.query("Pressure > 30.20")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 2)
# Empty DataFrame
# Columns: [Date, Pressure]
# Index: []

# %%
anomalias = pressure.query("Pressure < 29.60")
print(anomalias.shape)
print(anomalias.head(anomalias.shape[0]))
# Out:
# (0, 2)
# Empty DataFrame
# Columns: [Date, Pressure]
# Index: []
